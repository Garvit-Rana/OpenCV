# %%
import cv2

# %%
img =cv2.imread('messi.jpg',0)

# %%
cv2.imshow('yaa!!',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.imwrite('messigrey.jpg',img)
# Out:
# True

# %%
cap=cv2.VideoCapture(0)
while(True):
    ret,frame=cap.read()
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    cv2.imshow('hello',gray)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()

# %%
import numpy as np
im=np.zeros((500,500,3))
img=cv2.line(im,(0,0),(200,200),(255,0,0),5)
cv2.imshow("frame",img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
font = cv2.FONT_HERSHEY_SIMPLEX
a=cv2.putText(im,'Rana',(10,500), font, 4,(255,255,255),2,cv2.LINE_AA)
cv2.imshow("fr",a)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

def nothing(x):
    pass

# Create a black image, a window
img = np.zeros((300,512,3), np.uint8)
cv2.namedWindow('image')

# create trackbars for color change
cv2.createTrackbar('R','image',0,255,nothing)
cv2.createTrackbar('G','image',0,255,nothing)
cv2.createTrackbar('B','image',0,255,nothing)

# create switch for ON/OFF functionality
switch = '0 : OFF \n1 : ON'
cv2.createTrackbar(switch, 'image',0,1,nothing)

while(1):
    cv2.imshow('image',img)
    k = cv2.waitKey(1000) & 0xFF
    if k == 27:
        break

    # get current positions of four trackbars
    r = cv2.getTrackbarPos('R','image')
    g = cv2.getTrackbarPos('G','image')
    b = cv2.getTrackbarPos('B','image')
    s = cv2.getTrackbarPos(switch,'image')

    if s == 0:
        img[:] = 0
    else:
        img[:] = [b,g,r]

cv2.destroyAllWindows()

# %%
img=cv2.imread('messi.jpg',-1)
px=img[100,100]
print(px)
img[100,100]=[255,20,44]
px=img[100,100]
print(px)
cv2.imshow("fr",img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# [14 26 30]
# [255  20  44]

# %%
img.item(100,100,2)
# Out:
# 44

# %%
img.itemset((100,100,2),30)
img.item(100,100,2)
# Out:
# 30

# %%
print (img.shape)
# Out:
# (768, 768, 3)

# %%
ball=img[150:500,480:780]
cv2.imshow("fr",ball)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img[0:350,0:288]=ball
cv2.imshow("fr",img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
from matplotlib import pyplot as plt

BLUE = [255,0,0]

img1 = cv2.imread('messi.jpg')

replicate = cv2.copyMakeBorder(img1,10,10,10,10,cv2.BORDER_REPLICATE)
reflect = cv2.copyMakeBorder(img1,10,10,10,10,cv2.BORDER_REFLECT)
reflect101 = cv2.copyMakeBorder(img1,10,10,10,10,cv2.BORDER_REFLECT_101)
wrap = cv2.copyMakeBorder(img1,10,10,10,10,cv2.BORDER_WRAP)
constant= cv2.copyMakeBorder(img1,10,10,10,10,cv2.BORDER_CONSTANT,value=BLUE)

plt.subplot(231),plt.imshow(img1,'gray'),plt.title('ORIGINAL')
plt.subplot(232),plt.imshow(replicate,'gray'),plt.title('REPLICATE')
plt.subplot(233),plt.imshow(reflect,'gray'),plt.title('REFLECT')
plt.subplot(234),plt.imshow(reflect101,'gray'),plt.title('REFLECT_101')
plt.subplot(235),plt.imshow(wrap,'gray'),plt.title('WRAP')
plt.subplot(236),plt.imshow(constant,'gray'),plt.title('CONSTANT')

plt.show()

# %%
img=cv2.imread('messi.jpg',-1)
img1=cv2.imread("ron.jpg",-1)
a=cv2.add(cv2.resize(img, (500, 550)) ,cv2.resize(img1, (500, 550)) )
cv2.imshow("fr",a)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
b=cv2.addWeighted(cv2.resize(img, (500, 550)),0.9,cv2.resize(img1, (500, 550)) ,0.5,0)
cv2.imshow("fr",b)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img=cv2.imread("messi.jpg",-1)
px=cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
a=np.array([25,50,50])
b=np.array([32,255,255])
mask=cv2.inRange(px,a,b)
final=cv2.bitwise_and(px,px,mask=mask)
cv2.imshow('frame',px)
cv2.imshow('mask',mask)
cv2.imshow('res',final)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
im=cv2.imread("messigrey.jpg",-1)
print(im[100,200])
# Out:
# 23

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('messi.jpg',0)
ret,thresh1 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)
cv2.imshow("fr",img)
cv2.imshow("se",thresh1)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img=cv2.imread("messi.jpg",-1)
blur=cv2.blur(img,(10,10))
cv2.imshow("se",blur)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img=cv2.imread("j.png",0)
kernel=np.ones((5,5))
erose=cv2.erode(img,kernel,iterations=2)
cv2.imshow("se",erose)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
dilation = cv2.dilate(img,kernel,iterations = 1)
cv2.imshow("se",dilation)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
gradient = cv2.morphologyEx(img, cv2.MORPH_GRADIENT, kernel)
cv2.imshow("se",gradient)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np
img=cv2.imread("ron.jpg",0)
corner=cv2.goodFeaturesToTrack(img,30,0.01,5)
corner
# Out:
# array([[[464., 341.]],
#
#        [[468., 328.]],
#
#        [[417., 329.]],
#
#        [[286., 538.]],
#
#        [[378., 179.]],
#
#        [[270., 477.]],
#
#        [[439., 329.]],
#
#        [[445., 330.]],
#
#        [[452., 342.]],
#
#        [[438., 338.]],
#
#        [[461., 348.]],
#
#        [[364., 269.]],
#
#        [[319., 205.]],
#
#        [[273., 742.]],
#
#        [[424., 340.]],
#
#        [[359., 180.]],
#
#        [[326., 679.]],
#
#        [[383., 269.]],
#
#        [[453., 357.]],
#
#        [[258., 484.]],
#
#        [[410., 329.]],
#
#        [[483., 245.]],
#
#        [[263., 483.]],
#
#        [[410., 337.]],
#
#        [[363., 177.]],
#
#        [[468., 188.]],
#
#        [[435., 870.]],
#
#        [[472., 243.]],
#
#        [[314., 194.]],
#
#        [[347., 210.]]], dtype=float32)

# %%
corner=np.int0(corner)
im =cv2.imread("ron.jpg",1)
for i in corner:
    x,y=i.ravel()
    cv2.circle(im,(x,y),3,255,-1)
plt.imshow(im)
plt.show()

# %%
cv2.imshow("frame",im)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('haarcascade_eye.xml')
smile_cascade=cv2.CascadeClassifier('haarcascade_smile.xml')
img = cv2.imread('messi.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
faces = face_cascade.detectMultiScale(gray, 1.3, 5)
for (x,y,w,h) in faces:
    img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    #smile=smile_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)

        
cv2.imshow('img',img)
cv2.waitKey(0)
cv2.destroyAllWindows()
